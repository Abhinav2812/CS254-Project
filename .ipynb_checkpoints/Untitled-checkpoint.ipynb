# %%
# %config IPCompleter.greedy=True
# %matplotlib inline
import networkx as nx
from networkx.drawing.nx_agraph import write_dot, graphviz_layout, to_agraph
import matplotlib.pyplot as plt
nodecolors = {}
G = nx.DiGraph()
def drawGraph():
    pos =graphviz_layout(G, prog='dot')
    edges = G.edges()
    colors = [nodecolors[u][v] for u,v in edges]
    nx.draw(G, pos, with_labels=False, arrows=True, edge_color=colors)
    
def add_Edge(From, To, color='black'):
    if From in nodecolors:
        nodecolors[From][To] = color
    else:
        nodecolors[From] = {To:color}
    
def createGraph():
    G.add_node("ROOT")
    for i in range(5):
        G.add_node("Child_%i" % i)
        G.add_node("Grandchild_%i" % i)
        G.add_node("Greatgrandchild_%i" % i)
        add_edge("ROOT", "Child_%i" % i)
        add_edge("Child_%i" % i, "Grandchild_%i" % i)
        add_edge("Grandchild_%i" % i, "Greatgrandchild_%i" % i)
createGraph()
drawGraph()

# %%
G.remove_edge("ROOT","Child_1")
drawgraph()
